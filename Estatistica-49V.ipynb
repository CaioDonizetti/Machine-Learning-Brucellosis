# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Biblioteca para fazer a PADRONIZAÇÃO
from sklearn.preprocessing import StandardScaler

# Biblioteca para fazer a NORMALIZAÇÃO
from sklearn.preprocessing import MinMaxScaler

# Bilioteca para separação de dados em treino e teste
from sklearn.model_selection import train_test_split

# Biblioteca para calcular a acuracia do modelo
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

from kseg_py import *

from imblearn.over_sampling import ADASYN

from scipy.stats import tukey_hsd
from scipy import stats

# %%
KNN_rep = pd.read_csv("../Resultados/KNN_49V_rep.csv", na_values='?')
KNN_adasyn = pd.read_csv("../Resultados/KNN_49V_adasyn.csv", na_values='?')
KNN_contr = pd.read_csv("../Resultados/KNN_49V_contr.csv", na_values='?')

Kseg_rep = pd.read_csv("../Resultados/Kseg_49V_rep.csv", na_values='?')
Kseg_adasyn = pd.read_csv("../Resultados/Kseg_49V_adasyn.csv", na_values='?')
Kseg_contr = pd.read_csv("../Resultados/Kseg_49V_contr.csv", na_values='?')

RNA_rep = pd.read_csv("../Resultados/RNA_49V_rep.csv", na_values='?')
RNA_adasyn = pd.read_csv("../Resultados/RNA_49V_adasyn.csv", na_values='?')
RNA_contr = pd.read_csv("../Resultados/RNA_49V_contr.csv", na_values='?')

SVM_rep = pd.read_csv("../Resultados/SVM_49V_rep.csv", na_values='?')
SVM_adasyn = pd.read_csv("../Resultados/SVM_49V_adasyn.csv", na_values='?')
SVM_contr = pd.read_csv("../Resultados/SVM_49V_contr.csv", na_values='?')

# %% [markdown]
# ### **ACCURACY**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15, 4))

axs[0].boxplot([RNA_rep.RNA_accuracy_rep, RNA_adasyn.RNA_accuracy_adasyn, RNA_contr.RNA_accuracy_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_ylabel("Acurácia 49V")
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_accuracy_rep, KNN_adasyn.KNN_accuracy_adasyn, KNN_contr.KNN_accuracy_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_accuracy_rep, SVM_adasyn.SVM_accuracy_adasyn, SVM_contr.SVM_accuracy_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_accuracy_rep, Kseg_adasyn.Kseg_accuracy_adasyn, Kseg_contr.Kseg_accuracy_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()

# %% [markdown]
# ### **NEGATIVO PRECISION**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15, 4))

axs[0].set_ylabel("NEGATIVO PRECISION 49V")

axs[0].boxplot([RNA_rep.RNA_neg_prec_rep, RNA_adasyn.RNA_neg_prec_adasyn, RNA_contr.RNA_neg_prec_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_neg_prec_rep, KNN_adasyn.KNN_neg_prec_adasyn, KNN_contr.KNN_neg_prec_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_neg_prec_rep, SVM_adasyn.SVM_neg_prec_adasyn, SVM_contr.SVM_neg_prec_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_neg_prec_rep, Kseg_adasyn.Kseg_neg_prec_adasyn, Kseg_contr.Kseg_neg_prec_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()

# %% [markdown]
# ### **POSITIVO PRECISION**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(20, 4))

axs[0].set_ylabel("POSITIVO PRECISION 49V")

axs[0].boxplot([RNA_rep.RNA_pos_prec_rep, RNA_adasyn.RNA_pos_prec_adasyn, RNA_contr.RNA_pos_prec_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_pos_prec_rep, KNN_adasyn.KNN_pos_prec_adasyn, KNN_contr.KNN_pos_prec_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_pos_prec_rep, SVM_adasyn.SVM_pos_prec_adasyn, SVM_contr.SVM_pos_prec_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_pos_prec_rep, Kseg_adasyn.Kseg_pos_prec_adasyn, Kseg_contr.Kseg_pos_prec_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()

# %% [markdown]
# ### **NEGATIVO RECALL**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15, 4))

axs[0].set_ylabel("NEGATIVO RECALL 49V")

axs[0].boxplot([RNA_rep.RNA_neg_recall_rep, RNA_adasyn.RNA_neg_recall_adasyn, RNA_contr.RNA_neg_recall_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_neg_recall_rep, KNN_adasyn.KNN_neg_recall_adasyn, KNN_contr.KNN_neg_recall_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_neg_recall_rep, SVM_adasyn.SVM_neg_recall_adasyn, SVM_contr.SVM_neg_recall_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_neg_recall_rep, Kseg_adasyn.Kseg_neg_recall_adasyn, Kseg_contr.Kseg_neg_recall_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()

# %% [markdown]
# ### **POSITIVO RECALL**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15, 4))

axs[0].set_ylabel("POSITIVO RECALL 49V")

axs[0].boxplot([RNA_rep.RNA_pos_recall_rep, RNA_adasyn.RNA_pos_recall_adasyn, RNA_contr.RNA_pos_recall_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_pos_recall_rep, KNN_adasyn.KNN_pos_recall_adasyn, KNN_contr.KNN_pos_recall_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_pos_recall_rep, SVM_adasyn.SVM_pos_recall_adasyn, SVM_contr.SVM_pos_recall_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_pos_recall_rep, Kseg_adasyn.Kseg_pos_recall_adasyn, Kseg_contr.Kseg_pos_recall_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()

# %% [markdown]
# ### **NEGATIVO F1-SCORE**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(15, 4))

axs[0].set_ylabel("NEGATIVO F1-SCORE 49V")

axs[0].boxplot([RNA_rep.RNA_neg_fscore_rep, RNA_adasyn.RNA_neg_fscore_adasyn, RNA_contr.RNA_neg_fscore_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_neg_fscore_rep, KNN_adasyn.KNN_neg_fscore_adasyn, KNN_contr.KNN_neg_fscore_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_neg_fscore_rep, SVM_adasyn.SVM_neg_fscore_adasyn, SVM_contr.SVM_neg_fscore_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_neg_fscore_rep, Kseg_adasyn.Kseg_neg_fscore_adasyn, Kseg_contr.Kseg_neg_fscore_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()

# %% [markdown]
# ### **POSITIVO F1-SCORE**

# %%
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(20, 4))

axs[0].set_ylabel("POSITIVO F1-SCORE 49V")

axs[0].boxplot([RNA_rep.RNA_pos_fscore_rep, RNA_adasyn.RNA_pos_fscore_adasyn, RNA_contr.RNA_pos_fscore_contr])
axs[0].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[0].set_title('RNA')

axs[1].boxplot([KNN_rep.KNN_pos_fscore_rep, KNN_adasyn.KNN_pos_fscore_adasyn, KNN_contr.KNN_pos_fscore_contr])
axs[1].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[1].set_title('KNN')

axs[2].boxplot([SVM_rep.SVM_pos_fscore_rep, SVM_adasyn.SVM_pos_fscore_adasyn, SVM_contr.SVM_pos_fscore_contr])
axs[2].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[2].set_title('SVM')

axs[3].boxplot([Kseg_rep.Kseg_pos_fscore_rep, Kseg_adasyn.Kseg_pos_fscore_adasyn, Kseg_contr.Kseg_pos_fscore_contr])
axs[3].set_xticklabels(["Replicação", "ADASYN", "Controle"])
axs[3].set_title('Kseg')

plt.show()
